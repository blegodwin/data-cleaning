# %%
# import pandas library for data manipulation and numerical computation
import pandas as pd
import numpy as np

# %%
# read the csv file into a pandas dataframe
arewa = pd.read_csv(r"food_coded.csv")

# %%
# viewing data
arewa.head(10)
# Out:
#      GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0    2.4       2          1               430           NaN           315.0
# 1  3.654       1          1               610           3.0           420.0
# 2    3.3       1          1               720           4.0           420.0
# 3    3.2       1          1               430           3.0           420.0
# 4    3.5       1          1               720           2.0           420.0
# 5   2.25       1          1               610           3.0           980.0
# 6    3.8       2          1               610           3.0           420.0
# 7    3.3       1          1               720           3.0           420.0
# 8    3.3       1          1               430           NaN           420.0
# 9    3.3       1          1               430           3.0           315.0
#
#    coffee                                  comfort_food  \
# 0       1                                          none
# ...

# %%
# view tail of the dataset
arewa.tail(10)
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 115    3.3       2          1               610           4.0           980.0
# 116    3.4       1          1               610           NaN           420.0
# 117   3.77       1          1               610           NaN           315.0
# 118   3.63       1          1               430           3.0           420.0
# 119    3.2       2          1               610           3.0           420.0
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
#      coffee                                       comfort_food  \
# ...

# %%
# this function returns information about the dataset columns
arewa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           123 non-null    object
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  106 non-null    float64
#  5   calories_scone                124 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  124 non-null    object
#  8   comfort_food_reasons          124 non-null    object
#  9   comfort_food_reasons_coded    106 non-null    float64
#  10  cook                          122 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
# this function returns the number of rows and columns in the dataset
arewa.shape
# Out:
# (125, 61)

# %%
# this function returns the size of the dataframe; 
# the product of the number of values recorded in each row and column
arewa.size
# Out:
# 7625

# %% [markdown]
# This dataset has 61 columns with integer, float and object data types. The columns each have 125 data points respectively and it is evident that there are missing values in the dataset.

# %%
# accessing columns to inspect certain columns
arewa[['comfort_food','comfort_food_reasons_coded', 'comfort_food_reasons_coded.1']]
# Out:
#                                 comfort_food  comfort_food_reasons_coded  \
# 0                                       none                         9.0
# 1                chocolate, chips, ice cream                         1.0
# 2            frozen yogurt, pizza, fast food                         1.0
# 3           Pizza, Mac and cheese, ice cream                         2.0
# 4               Ice cream, chocolate, chips                          1.0
# ..                                       ...                         ...
# 120  wine. mac and cheese, pizza, ice cream                          NaN
# 121               Pizza / Wings / Cheesecake                         NaN
# 122               rice, potato, seaweed soup                         NaN
# 123             Mac n Cheese, Lasagna, Pizza                         NaN
# 124             Chocolates, pizza, and Ritz.                         NaN
#
#      comfort_food_reasons_coded.1
# 0                               9
# ...

# %% [markdown]
# # Inspecting and understanding the data
# From the inclusion of a GPA column, this dataset appears to be a collection of data from students about the food they eat, how aware of their food choices they are and other factors (such as mood, sports, etc) that may affect their food choices.
#
# This data may also aim to show how moods affect eating habits and calorie intake and in turn, net weight. The data points appear to have been taken from a student demographic that eat the same kind of food on the same or similar schedule.

# %%
 # this function return a view of the columns in the dataset
arewa.columns
# Out:
# Index(['GPA', 'Gender', 'breakfast', 'calories_chicken', 'calories_day',
#        'calories_scone', 'coffee', 'comfort_food', 'comfort_food_reasons',
#        'comfort_food_reasons_coded', 'cook', 'comfort_food_reasons_coded.1',
#        'cuisine', 'diet_current', 'diet_current_coded', 'drink',
#        'eating_changes', 'eating_changes_coded', 'eating_changes_coded1',
#        'eating_out', 'employment', 'ethnic_food', 'exercise',
#        'father_education', 'father_profession', 'fav_cuisine',
#        'fav_cuisine_coded', 'fav_food', 'food_childhood', 'fries', 'fruit_day',
#        'grade_level', 'greek_food', 'healthy_feeling', 'healthy_meal',
#        'ideal_diet', 'ideal_diet_coded', 'income', 'indian_food',
#        'italian_food', 'life_rewarding', 'marital_status',
#        'meals_dinner_friend', 'mother_education', 'mother_profession',
#        'nutritional_check', 'on_off_campus', 'parents_cook', 'pay_meal_out',
# ...

# %% [markdown]
# # Dealing with Incositent column names
#
# It can be observed from the column view the the text casing of the column names are inconsistent. These columns would be renamed.
#
# - Text case
#
# - Rename

# %%
# to give the columns uniform name cases, capitalize str function is used.
arewa.columns = arewa.columns.str.capitalize()

# %%
arewa.columns
# Out:
# Index(['Gpa', 'Gender', 'Breakfast', 'Calories_chicken', 'Calories_day',
#        'Calories_scone', 'Coffee', 'Comfort_food', 'Comfort_food_reasons',
#        'Comfort_food_reasons_coded', 'Cook', 'Comfort_food_reasons_coded.1',
#        'Cuisine', 'Diet_current', 'Diet_current_coded', 'Drink',
#        'Eating_changes', 'Eating_changes_coded', 'Eating_changes_coded1',
#        'Eating_out', 'Employment', 'Ethnic_food', 'Exercise',
#        'Father_education', 'Father_profession', 'Fav_cuisine',
#        'Fav_cuisine_coded', 'Fav_food', 'Food_childhood', 'Fries', 'Fruit_day',
#        'Grade_level', 'Greek_food', 'Healthy_feeling', 'Healthy_meal',
#        'Ideal_diet', 'Ideal_diet_coded', 'Income', 'Indian_food',
#        'Italian_food', 'Life_rewarding', 'Marital_status',
#        'Meals_dinner_friend', 'Mother_education', 'Mother_profession',
#        'Nutritional_check', 'On_off_campus', 'Parents_cook', 'Pay_meal_out',
# ...

# %%
# rename the GPA column as it is most appropriate in upper casing
arewa.rename(columns = {'Gpa' : 'GPA'}, inplace = True)

# %%
#arewa['Gpa'].rename('GPA')

# %%
arewa
# Out:
#        GPA  Gender  Breakfast  Calories_chicken  Calories_day  Calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %% [markdown]
# # Handling missing values
#
# How to go about it:
#
#     Add a default value.This can be the mean or the mode of values in the column.
#
#     You can delete rows with missing values, depending on the problem. e.g. a critical situation.
#
# However, confirm if there are missing values in the first place.

# %%
# checking for prescence of missing values in the whole dataset
arewa.isnull().any().any()
# Out:
# True

# %%
# checking for prescence of missng values in specific columns
arewa.isnull().any()
# Out:
# GPA                  True
# Gender              False
# Breakfast           False
# Calories_chicken    False
# Calories_day         True
#                     ...
# Type_sports          True
# Veggies_day         False
# Vitamins            False
# Waffle_calories     False
# Weight               True
# Length: 61, dtype: bool

# %%
# checking for missing values in the dataset rows
arewa.isnull()
# Out:
#        GPA  Gender  Breakfast  Calories_chicken  Calories_day  Calories_scone  \
# 0    False   False      False             False          True           False
# 1    False   False      False             False         False           False
# 2    False   False      False             False         False           False
# 3    False   False      False             False         False           False
# 4    False   False      False             False         False           False
# ..     ...     ...        ...               ...           ...             ...
# 120  False   False      False             False         False           False
# 121  False   False      False             False         False           False
# 122  False   False      False             False          True           False
# 123  False   False      False             False         False           False
# 124  False   False      False             False          True           False
#
# ...

# %%
# total numbers of missing values in the dataset
arewa.isnull().sum().sum()
# Out:
# 143

# %%
# numbers of missing values in each column of the dataset
arewa.isnull().sum()
# Out:
# GPA                  2
# Gender               0
# Breakfast            0
# Calories_chicken     0
# Calories_day        19
#                     ..
# Type_sports         21
# Veggies_day          0
# Vitamins             0
# Waffle_calories      0
# Weight               2
# Length: 61, dtype: int64

# %% [markdown]
# #### Dealing with numeric missing values
# Using the center off tendency (mean/ mode) to fill up missing values.

# %%
#arewa['Calories_day'].mean()

# %%
#arewa = arewa.Calories_day.fillna(arewa['Calories_day'].mean())

# %%
#arewa

# %% [markdown]
# Alternatively use the .fillna() method to fill in a specific value. Zero (0) is favoured to maintain original data

# %%
fill_arewa = arewa.fillna(0)

# %%
fill_arewa
# Out:
#        GPA  Gender  Breakfast  Calories_chicken  Calories_day  Calories_scone  \
# 0      2.4       2          1               430           0.0           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           0.0           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           0.0           315.0
#
# ...

# %%
arewa['Calories_day'].mean()
# this line of code is not assigned to a variable as we do not need it to be reproducable
# Out:
# 3.0283018867924527

# %%
with_mean = arewa.Calories_day.fillna(arewa['Calories_day'].mean(), inplace = True)
# using the inplace kwarg to save changes to the dataframe arewa.

# %%
#with_mean

# %%
arewa
# the 'Calories_day' column have been filled inplace with the mean.
# Out:
#        GPA  Gender  Breakfast  Calories_chicken  Calories_day  Calories_scone  \
# 0      2.4       2          1               430      3.028302           315.0
# 1    3.654       1          1               610      3.000000           420.0
# 2      3.3       1          1               720      4.000000           420.0
# 3      3.2       1          1               430      3.000000           420.0
# 4      3.5       1          1               720      2.000000           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610      4.000000           420.0
# 121      3       1          1               265      2.000000           315.0
# 122  3.882       1          1               720      3.028302           420.0
# 123      3       2          1               720      4.000000           420.0
# 124    3.9       1          1               430      3.028302           315.0
#
# ...

# %%
# the missing values can be droped too.
# the code to drop the missing value has been assigned to a variable
# using the "Weight" column with only two missing values
weight_drop = arewa['Weight'].dropna()

# %%
weight_drop
# Out:
# 0                           187
# 1                           155
# 2      I'm not answering this.
# 3                 Not sure, 240
# 4                           190
#                  ...
# 120                         156
# 121                         180
# 122                         120
# 123                         135
# 124                         135
# Name: Weight, Length: 123, dtype: object

# %%
# checking column for any missing value
weight_drop.isnull().any()
# Out:
# False

# %%
# checking the sum of missing values in the column.
# the code returns 0, which means all the missing values have been droped.
weight_drop.isnull().sum()
# Out:
# 0

# %%
# what to do with missing values in categorical variables?

# %% [markdown]
# ### The forward ffill() function
#
# this can be used to fill any missing value with the previous value - the value directly above it.
#
# ### the backwardfill() function, bfill()
#
# use to fill missing value if there are no values in front of it or are at the end of the dataset.

# %%
arewa.ffill(inplace = True)

# %%
arewa
# Out:
#        GPA  Gender  Breakfast  Calories_chicken  Calories_day  Calories_scone  \
# 0      2.4       2          1               430      3.028302           315.0
# 1    3.654       1          1               610      3.000000           420.0
# 2      3.3       1          1               720      4.000000           420.0
# 3      3.2       1          1               430      3.000000           420.0
# 4      3.5       1          1               720      2.000000           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610      4.000000           420.0
# 121      3       1          1               265      2.000000           315.0
# 122  3.882       1          1               720      3.028302           420.0
# 123      3       2          1               720      4.000000           420.0
# 124    3.9       1          1               430      3.028302           315.0
#
# ...

# %%
# using function to check if there are any missing values.
arewa.isnull().any()
# Out:
# GPA                 False
# Gender              False
# Breakfast           False
# Calories_chicken    False
# Calories_day        False
#                     ...
# Type_sports         False
# Veggies_day         False
# Vitamins            False
# Waffle_calories     False
# Weight              False
# Length: 61, dtype: bool

# %%
# check number of missing values
arewa.isnull().sum()
# Out:
# GPA                 0
# Gender              0
# Breakfast           0
# Calories_chicken    0
# Calories_day        0
#                    ..
# Type_sports         0
# Veggies_day         0
# Vitamins            0
# Waffle_calories     0
# Weight              0
# Length: 61, dtype: int64

# %% [raw]
# arewa.isnull().sum().sum()

# %% [markdown]
# # Dealing with duplicates

# %%
# check for duplicates
arewa.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No duplicates present. No unique ID present either.

# %% [markdown]
# # Data Transformation
#
# - round up float column to two decimal places
#
# - truncate values. separate numeric data from text.

# %%
arewa['GPA'].info
# Out:
# <bound method Series.info of 0        2.4
# 1      3.654
# 2        3.3
# 3        3.2
# 4        3.5
#        ...
# 120      3.5
# 121        3
# 122    3.882
# 123        3
# 124      3.9
# Name: GPA, Length: 125, dtype: object>

# %% [markdown]
# Notice how the column type is  object although it seemingly contain floats?

# %%
# convert column type from object to float
arewa[['GPA']] = arewa[['GPA']].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5928\2466721261.py in <module>
#       1 # convert column type from object to float
# ----> 2 arewa[['GPA']] = arewa[['GPA']].astype(float)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %% [markdown]
# The error message above shows Type Error. The column contains the str value 'personal'

# %%
# the functioncconverts the column to numeric type and invalid entries are converted to NaN
arewa[['GPA']] = arewa[['GPA']].apply(pd.to_numeric, errors = 'coerce')

# %%
# the numeric float values are rounded up to two decimal places
arewa['GPA'] = arewa['GPA'].round(2)

# %%
arewa
# Out:
#       GPA  Gender  Breakfast  Calories_chicken  Calories_day  Calories_scone  \
# 0    2.40       2          1               430      3.028302           315.0
# 1    3.65       1          1               610      3.000000           420.0
# 2    3.30       1          1               720      4.000000           420.0
# 3    3.20       1          1               430      3.000000           420.0
# 4    3.50       1          1               720      2.000000           420.0
# ..    ...     ...        ...               ...           ...             ...
# 120  3.50       1          1               610      4.000000           420.0
# 121  3.00       1          1               265      2.000000           315.0
# 122  3.88       1          1               720      3.028302           420.0
# 123  3.00       2          1               720      4.000000           420.0
# 124  3.90       1          1               430      3.028302           315.0
#
# ...

# %% [markdown]
# ##### Separate numeric value attached to string value

# %%
arewa['Weight'].isnull().any()
# Out:
# False

# %%
# using the "Weight" column
arewa['Weight'] = arewa['Weight'].str.replace(r'\D', '', regex = True).replace('', np.nan)

# %%
arewa['Weight']
# Out:
# 0      187
# 1      155
# 2      NaN
# 3      240
# 4      190
#       ...
# 120    156
# 121    180
# 122    120
# 123    135
# 124    135
# Name: Weight, Length: 125, dtype: object

# %% [markdown]
# In the 'Weight' column, the function and it's positional args remove all non-numeric characters and values that are just string types to NaN. This column is still an object type and can be converted to int.

# %%
arewa['Weight'] = arewa['Weight'].apply(pd.to_numeric, errors = 'coerce').astype

# %%
arewa['Weight']
# Out:
# 0      187.0
# 1      155.0
# 2        NaN
# 3      240.0
# 4      190.0
#        ...
# 120    156.0
# 121    180.0
# 122    120.0
# 123    135.0
# 124    135.0
# Name: Weight, Length: 125, dtype: float64
